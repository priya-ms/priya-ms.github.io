# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# %pip install --upgrade requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /home/priya/.local/lib/python3.8/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/priya/.local/lib/python3.8/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/priya/.local/lib/python3.8/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests) (2019.11.28)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: getorg in /home/priya/.local/lib/python3.8/site-packages (0.3.1)
# Requirement already satisfied: geopy in /home/priya/.local/lib/python3.8/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /home/priya/.local/lib/python3.8/site-packages (from getorg) (2.5.0)
# Requirement already satisfied: retrying in /home/priya/.local/lib/python3.8/site-packages (from getorg) (1.3.4)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/priya/.local/lib/python3.8/site-packages (from geopy->getorg) (2.0)
# Requirement already satisfied: pynacl>=1.4.0 in /home/priya/.local/lib/python3.8/site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /home/priya/.local/lib/python3.8/site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/priya/.local/lib/python3.8/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.9.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/priya/.local/lib/python3.8/site-packages (from pygithub->getorg) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /home/priya/.local/lib/python3.8/site-packages (from pygithub->getorg) (2.2.3)
# Requirement already satisfied: Deprecated in /home/priya/.local/lib/python3.8/site-packages (from pygithub->getorg) (1.2.15)
# Requirement already satisfied: six>=1.7.0 in /usr/lib/python3/dist-packages (from retrying->getorg) (1.14.0)
# Requirement already satisfied: cryptography>=3.4.0 in /home/priya/.local/lib/python3.8/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (44.0.0)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from pynacl>=1.4.0->pygithub->getorg) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/priya/.local/lib/python3.8/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.14.0->pygithub->getorg) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.14.0->pygithub->getorg) (2019.11.28)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/priya/.local/lib/python3.8/site-packages (from Deprecated->pygithub->getorg) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.20)
# Note: you may need to restart the kernel to use updated packages.
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim(user_agent='http')
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Erandwane, Pune, India
#  Erandwane, Pune City, Pune, Maharashtra, 411004, India
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Kolkata, India
#  Kolkata, West Bengal, India
# Siruseri, Chennai, India
#  Endo India, Par Formulation, Pudupakkam - Sirucheri Road, Pudupakkam, Tiruporur, Chengalpattu, Tamil Nadu, 603103, India
# Bangalore, India
#  Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, India
# Bangalore, India
#  Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, India
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Pune, India
#  Pune City, Pune, Maharashtra, India
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Baner, Pune, India
#  Baner, Pune City, Pune, Maharashtra, 511045, India
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Bangalore, India
#  Bengaluru, Bangalore North, Bengaluru Urban, Karnataka, India
# Münster, Germany
#  Münster, Nordrhein-Westfalen, Deutschland
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Powai, India
#  Powai, Zone 6, Mumbai Suburban, Maharashtra, 400076, India
# Nafpaktos, Greece
#  Ναύπακτος, Δημοτική Ενότητα Ναυπάκτου, Δήμος Ναυπακτίας, Περιφερειακή Ενότητα Αιτωλοακαρνανίας, Περιφέρεια Δυτικής Ελλάδας, Αποκεντρωμένη Διοίκηση Πελοποννήσου, Δυτικής Ελλάδας και Ιονίου, 303 00, Ελλάς
# Thiruporur, India
#  Tiruporur, Chengalpattu, Tamil Nadu, India

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
